# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-09-10 13:42:57--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip.1’
#
# online+retail.zip.1     [    <=>             ]  22.62M  29.7MB/s    in 0.8s
#
# 2025-09-10 13:42:58 (29.7 MB/s) - ‘online+retail.zip.1’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
# replace Online Retail.xlsx? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
df1=pd.read_excel('Online Retail.xlsx',dtype={'InvoiceNo':'string','StockCode':'string','Description':'string','Country':'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(1), string(4)
# memory usage: 33.1 MB

# %%
df1[df1.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# 1987          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
most_freq =df1[["StockCode","Description"]].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787    35833P                               check      1
# 4788     21410     COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412            VINTAGE GOLD TINSEL REEL      1
# 4790     21414             SCALLOP SHELL SOAP DISH      1
# 4791     35972                               check      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode=="85123A"].head(1) #multiple descriptions with one stockcode but we picked the mode
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq=most_freq.groupby("StockCode").head(1)
most_freq
# Out:
#      StockCode                          Description  count
# 0       85123A   WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423             REGENCY CAKESTAND 3 TIER   2200
# 2       85099B              JUMBO BAG RED RETROSPOT   2159
# 3        47566                        PARTY BUNTING   1727
# 4        20725              LUNCH BAG RED RETROSPOT   1638
# ...        ...                                  ...    ...
# 4784     35832  WOOLLY HAT SOCK GLOVE ADVENT STRING      1
# 4785    35833G         4 GOLD FLOCK CHRISTMAS BALLS      1
# 4788     21410      COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412             VINTAGE GOLD TINSEL REEL      1
# 4790     21414              SCALLOP SHELL SOAP DISH      1
#
# [3958 rows x 3 columns]

# %%
most_freq.columns=["StockCode","freq_description","count"]
df2=df1.merge(most_freq,on="StockCode",how="left")
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
#
#                      freq_description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                 WHITE METAL LANTERN   328.0
# 2      CREAM CUPID HEARTS COAT HANGER   293.0

# %%
df2[df2.Description.isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139        <NA>        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134        <NA>         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145        <NA>         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509        <NA>         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A        <NA>         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country                  freq_description  count
# 622          NaN  United Kingdom  RETROSPOT TEA SET CERAMIC 11 PC   988.0
# 1970         NaN  United Kingdom                              <NA>    NaN
# 1971         NaN  United Kingdom   CHRISTMAS CRAFT HEART STOCKING     1.0
# 1972         NaN  United Kingdom        NEW ENGLAND MUG W GIFT BOX    2.0
# 1987         NaN  United Kingdom                              <NA>    NaN

# %%
df2["Description"]=df2["freq_description"]  #lets replace description with its most frequent attached to a stockcode
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
#
#                      freq_description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                 WHITE METAL LANTERN   328.0
# 2      CREAM CUPID HEARTS COAT HANGER   293.0

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# freq_description       112
# count                  112
# dtype: int64

# %%
df2.dropna(subset=['Description'],inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          134968
# Country                  0
# freq_description         0
# count                    0
# dtype: int64

# %%
df2[df2.CustomerID.isnull()].head()
# Out:
#      InvoiceNo StockCode                       Description  Quantity  \
# 622     536414     22139  RETROSPOT TEA SET CERAMIC 11 PC         56
# 1443    536544     21773   DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774   DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786                POLKADOT RAIN HAT          4
# 1446    536544     21787             RAIN PONCHO RETROSPOT         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country  \
# 622  2010-12-01 11:52:00       0.00         NaN  United Kingdom
# 1443 2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444 2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445 2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446 2010-12-01 14:32:00       1.66         NaN  United Kingdom
#
#                       freq_description  count
# 622   RETROSPOT TEA SET CERAMIC 11 PC   988.0
# 1443   DECORATIVE ROSE BATHROOM BOTTLE  164.0
# 1444   DECORATIVE CATS BATHROOM BOTTLE  188.0
# 1445                POLKADOT RAIN HAT   236.0
# 1446             RAIN PONCHO RETROSPOT  252.0

# %%
df2.drop(columns=["freq_description","count"],inplace=True)
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df2.describe() #lets handle unnecesarry negative numbers
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541797.000000                         541797  541797.000000
# mean        9.555919  2011-07-04 14:06:48.671255296       4.612067
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:36:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 11:41:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.103428                            NaN      96.769831
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df2[df2.Quantity<0].head(5)
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
df3=df2[(df2.Quantity>0)&(df2.UnitPrice>0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID
# count  397884.000000
# mean    15294.423453
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.141560

# %%
#is the max value of quantity valid
df3.Quantity.quantile(0.9999)
#what!!! ahh 99.99% are less than 1500 be conscious
# Out:
# np.float64(1439.8763999990188)

# %% [markdown]
# **Feature Engineering:Create New Columns**

# %%
df4=df3.copy()
df4["TotalPrice"]=df4["Quantity"]*df4["UnitPrice"]
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00

# %%
df4['Month']=df4['InvoiceDate'].dt.month
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
#
#    Month
# 0     12
# 1     12
# 2     12

# %% [markdown]
# 1.Plot Monthly Sales

# %%
monthly_sales=df4.groupby("Month")

# %%
for title,data in monthly_sales:
  print(title)
  print(data.head(3))
# Out:
# 1
#       InvoiceNo StockCode              Description  Quantity  \
# 42481    539993     22386  JUMBO BAG PINK POLKADOT        10
# 42482    539993     21499       BLUE POLKADOT WRAP        25
# 42483    539993     21498      RED RETROSPOT WRAP         25
#
#               InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 42481 2011-01-04 10:00:00       1.95     13313.0  United Kingdom        19.5
# 42482 2011-01-04 10:00:00       0.42     13313.0  United Kingdom        10.5
# 42483 2011-01-04 10:00:00       0.42     13313.0  United Kingdom        10.5
#
#        Month
# 42481      1
# 42482      1
# 42483      1
# 2
#       InvoiceNo StockCode                     Description  Quantity  \
# 77628    542776     21671    RED SPOT CERAMIC DRAWER KNOB        48
# 77629    542776     21668  RED STRIPE CERAMIC DRAWER KNOB        12
# 77630    542776     21670   BLUE SPOT CERAMIC DRAWER KNOB        12
#
#               InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 77628 2011-02-01 08:23:00       1.25     15240.0  United Kingdom        60.0
# 77629 2011-02-01 08:23:00       1.25     15240.0  United Kingdom        15.0
# 77630 2011-02-01 08:23:00       1.25     15240.0  United Kingdom        15.0
#
#        Month
# 77628      2
# 77629      2
# 77630      2
# 3
#        InvoiceNo StockCode                        Description  Quantity  \
# 105335    545220     21955  DOORMAT UNION JACK GUNS AND ROSES         2
# 105336    545220     48194                     DOORMAT HEARTS         2
# 105337    545220     22556     PLASTERS IN TIN CIRCUS PARADE         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 105335 2011-03-01 08:30:00       7.95     14620.0  United Kingdom        15.9
# 105336 2011-03-01 08:30:00       7.95     14620.0  United Kingdom        15.9
# 105337 2011-03-01 08:30:00       1.65     14620.0  United Kingdom        19.8
#
#         Month
# 105335      3
# 105336      3
# 105337      3
# 4
#        InvoiceNo StockCode                  Description  Quantity  \
# 142083    548550     22662  LUNCH BAG DOLLY GIRL DESIGN        10
# 142084    548550     22296    HEART IVORY TRELLIS LARGE        12
# 142085    548550     21790           VINTAGE SNAP CARDS        12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 142083 2011-04-01 08:22:00       1.65     18161.0  United Kingdom        16.5
# 142084 2011-04-01 08:22:00       1.65     18161.0  United Kingdom        19.8
# 142085 2011-04-01 08:22:00       0.85     18161.0  United Kingdom        10.2
#
#         Month
# 142083      4
# 142084      4
# 142085      4
# 5
#        InvoiceNo StockCode                    Description  Quantity  \
# 171999    551515     21731  RED TOADSTOOL LED NIGHT LIGHT        12
# 172000    551515     20749     ASSORTED COLOUR MINI CASES        12
# 172001    551515     22729    ALARM CLOCK BAKELIKE ORANGE         8
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 171999 2011-05-01 10:51:00       1.65     15606.0  United Kingdom        19.8
# 172000 2011-05-01 10:51:00       6.35     15606.0  United Kingdom        76.2
# 172001 2011-05-01 10:51:00       3.75     15606.0  United Kingdom        30.0
#
#         Month
# 171999      5
# 172000      5
# 172001      5
# 6
#        InvoiceNo StockCode                   Description  Quantity  \
# 209029    555156     23299  FOOD COVER WITH BEADS SET 2          6
# 209030    555156     22847   BREAD BIN DINER STYLE IVORY         1
# 209031    555157     23075     PARLOUR CERAMIC WALL HOOK        16
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 209029 2011-06-01 07:37:00       3.75     15643.0  United Kingdom       22.50
# 209030 2011-06-01 07:37:00      16.95     15643.0  United Kingdom       16.95
# 209031 2011-06-01 07:38:00       4.15     15643.0  United Kingdom       66.40
#
#         Month
# 209029      6
# 209030      6
# 209031      6
# 7
#        InvoiceNo StockCode                     Description  Quantity  \
# 245903    558638     84836     ZINC METAL HEART DECORATION        12
# 245904    558638     71459  HANGING JAM JAR T-LIGHT HOLDER        24
# 245905    558638     22784           LANTERN CREAM GAZEBO          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 245903 2011-07-01 08:16:00       1.25     16317.0  United Kingdom       15.00
# 245904 2011-07-01 08:16:00       0.85     16317.0  United Kingdom       20.40
# 245905 2011-07-01 08:16:00       4.95     16317.0  United Kingdom       14.85
#
#         Month
# 245903      7
# 245904      7
# 245905      7
# 8
#        InvoiceNo StockCode                      Description  Quantity  \
# 285421    561904     22075     6 RIBBONS ELEGANT CHRISTMAS         96
# 285422    561904    85049E        SCANDINAVIAN REDS RIBBONS       156
# 285423    561905     21385  IVORY HANGING DECORATION  HEART        24
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 285421 2011-08-01 08:30:00       1.45     17941.0  United Kingdom      139.20
# 285422 2011-08-01 08:30:00       1.06     17941.0  United Kingdom      165.36
# 285423 2011-08-01 09:31:00       0.85     14947.0  United Kingdom       20.40
#
#         Month
# 285421      8
# 285422      8
# 285423      8
# 9
#        InvoiceNo StockCode                 Description  Quantity  \
# 320705    565080     20677          PINK POLKADOT BOWL         8
# 320706    565080     22128  PARTY CONES CANDY ASSORTED        24
# 320708    565082     22423    REGENCY CAKESTAND 3 TIER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 320705 2011-09-01 08:25:00       1.25     13509.0  United Kingdom        10.0
# 320706 2011-09-01 08:25:00       1.25     13509.0  United Kingdom        30.0
# 320708 2011-09-01 09:15:00      12.75     13305.0  United Kingdom        25.5
#
#         Month
# 320705      9
# 320706      9
# 320708      9
# 10
#        InvoiceNo StockCode                Description  Quantity  \
# 370931    569203     79321              CHILLI LIGHTS        48
# 370932    569203     21154  RED RETROSPOT OVEN GLOVE         20
# 370933    569204     21790         VINTAGE SNAP CARDS         4
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 370931 2011-10-02 10:32:00       4.95     16353.0  United Kingdom       237.6
# 370932 2011-10-02 10:32:00       1.25     16353.0  United Kingdom        25.0
# 370933 2011-10-02 10:43:00       0.85     16591.0  United Kingdom         3.4
#
#         Month
# 370931     10
# 370932     10
# 370933     10
# 11
#        InvoiceNo StockCode                         Description  Quantity  \
# 431673    573744     21314       SMALL GLASS HEART TRINKET POT         8
# 431674    573744     21704             BAG 250g SWIRLY MARBLES        12
# 431675    573744     21791  VINTAGE HEADS AND TAILS CARD GAME         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 431673 2011-11-01 08:16:00       2.10     17733.0  United Kingdom        16.8
# 431674 2011-11-01 08:16:00       0.85     17733.0  United Kingdom        10.2
# 431675 2011-11-01 08:16:00       1.25     17733.0  United Kingdom        15.0
#
#         Month
# 431673     11
# 431674     11
# 431675     11
# 12
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
#
#    Month
# 0     12
# 1     12
# 2     12

# %%
monthly_sales=monthly_sales.TotalPrice.sum()

# %%
monthly_sales.plot(kind="line",title="Monthly Sales",marker="o")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid()
plt.show()

# %% [markdown]
# **Insights**
#
#  Total Sales started rising after August having a peak in November. This is likely due to the holiday Season at the end of the year

# %% [markdown]
# 2. Top 5 countries by sales

# %%
countries=df4.groupby("Country")

# %%
countries=countries.TotalPrice.sum().sort_values(ascending=False).head(5)

# %%
countries.plot(kind="barh",title="Top 5 Countries by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Country")
plt.grid(axis="x")
plt.show()
