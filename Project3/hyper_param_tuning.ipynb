# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn import svm

# %%
iris= load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['flower']=iris.target
df['flower_name']=df['flower'].apply(lambda x : iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    flower flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(iris.data, iris.target,test_size=0.3)

# %%
model=svm.SVC(C=20,gamma='auto')
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.9333333333333333

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(svm.SVC(kernel='linear',C=10,gamma='auto'),iris.data,iris.target,cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
import numpy as np

# %%
arr=cross_val_score(svm.SVC(kernel='rbf',C=20,gamma='auto'),iris.data,iris.target,cv=5)
print(np.average(arr))
# Out:
# 0.9666666666666668

# %%
kernels=['rbf','linear']
Cs=[1,10,20,30]
avg={}
for k in kernels:
    for C in Cs:
        cv_score=cross_val_score(svm.SVC(kernel=k,C=C,gamma='auto'),iris.data,iris.target,cv=5)
        avg[k + '_' + str(C)]=np.average(cv_score)
avg
# Out:
# {'rbf_1': np.float64(0.9800000000000001),
#  'rbf_10': np.float64(0.9800000000000001),
#  'rbf_20': np.float64(0.9666666666666668),
#  'rbf_30': np.float64(0.96),
#  'linear_1': np.float64(0.9800000000000001),
#  'linear_10': np.float64(0.9733333333333334),
#  'linear_20': np.float64(0.9666666666666666),
#  'linear_30': np.float64(0.96)}

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf=GridSearchCV(svm.SVC(gamma='auto'),{
    'C':[1,10,20,30],
    'kernel':['rbf','linear']
},cv=5)
clf.fit(iris.data,iris.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00462275, 0.00429678, 0.00475531, 0.00331168, 0.00258865,
#         0.00213895, 0.00183525, 0.00157881]),
#  'std_fit_time': array([2.92673325e-04, 1.98292777e-04, 7.09633689e-04, 7.72900794e-04,
#         2.41792674e-04, 4.76562507e-04, 4.73517992e-04, 9.77945234e-05]),
#  'mean_score_time': array([0.00387654, 0.00281367, 0.00326734, 0.00189638, 0.00193362,
#         0.00138564, 0.00137248, 0.00111303]),
#  'std_score_time': array([0.00070588, 0.0002223 , 0.00053829, 0.00032449, 0.00024998,
#         0.00035496, 0.00032327, 0.0001744 ]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
# ...

# %%
df_param=pd.DataFrame(clf.cv_results_)
df_param[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
clf.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
#if u have large computation cost for too many iterations use the randomisedsearchcv and the diff is the 
#n_iter argument which tells u the number of iterations you want

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_params={
    'svm':{
        'model':svm.SVC(gamma='auto'),
        'params':{
            'C':[1,10,20],
            'kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[5,10,20,30]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(multi_class='auto',max_iter=150),
        'params':{
            'C':[1,5,10],
            'solver':['newton-cg','lbfgs']
        }
    }
}

# %%
scores=[]
for model_name,np in model_params.items():
    clf=GridSearchCV(estimator=np['model'],param_grid=np['params'],cv=5)
    clf.fit(iris.data,iris.target)
    scores.append({
        'model':model_name,
        'best_score':clf.best_score_,
        'best_param':clf.best_params_
    })
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
scores
# Out:
# [{'model': 'svm',
#   'best_score': np.float64(0.9800000000000001),
#   'best_param': {'C': 1, 'kernel': 'rbf'}},
#  {'model': 'random_forest',
#   'best_score': np.float64(0.96),
#   'best_param': {'n_estimators': 30}},
#  {'model': 'logistic_regression',
#   'best_score': np.float64(0.9800000000000001),
#   'best_param': {'C': 5, 'solver': 'newton-cg'}}]

# %%
df=pd.DataFrame(scores,columns=['model','best_score','best_param'])
df
# Out:
#                  model  best_score                       best_param
# 0                  svm        0.98        {'C': 1, 'kernel': 'rbf'}
# 1        random_forest        0.96             {'n_estimators': 30}
# 2  logistic_regression        0.98  {'C': 5, 'solver': 'newton-cg'}

# %% [markdown]
# ## ASS
# # Tune the parameter of digits dataset

# %%
from sklearn.datasets import load_digits
from sklearn.tree import DecisionTreeClassifier

# %%
digits=load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
model_param={
     'svm':{
        'model':svm.SVC(gamma='auto'),
        'params':{
            'C':[1,10,20],
            'kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[5,10,20,30,90]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(multi_class='auto',max_iter=150),
        'params':{
            'C':[1,5,10],
            'solver':['newton-cg','lbfgs']
        }
    },
    'Decision_Tree':{
        'model':DecisionTreeClassifier(),
        'params':{
           'criterion': ['gini','entropy']
        }
    }
    
}

# %%
scores=[]
for model,np in model_param.items():
    clf=GridSearchCV(estimator= np['model'],param_grid=np['params'],cv=5)
    clf.fit(digits.data,digits.target)
    scores.append({
        'model':model,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
scores
# Out:
# [{'model': 'svm',
#   'best_score': np.float64(0.9476973073351903),
#   'best_params': {'C': 1, 'kernel': 'linear'}},
#  {'model': 'random_forest',
#   'best_score': np.float64(0.9432621479418136),
#   'best_params': {'n_estimators': 90}},
#  {'model': 'logistic_regression',
#   'best_score': np.float64(0.9154348498916743),
#   'best_params': {'C': 1, 'solver': 'lbfgs'}},
#  {'model': 'Decision_Tree',
#   'best_score': np.float64(0.814707520891365),
#   'best_params': {'criterion': 'entropy'}}]

# %%
df=pd.DataFrame(scores)

# %%
df[df.best_score==max()
